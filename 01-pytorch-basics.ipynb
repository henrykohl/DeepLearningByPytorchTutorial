# %%
jovian.commit()
# Out:
# [jovian] Detected Colab notebook...
# [jovian] Please enter your API key ( from https://jovian.ai/ ):
# API KEY:

# %% [markdown]
# # PyTorch Basics: Tensors & Gradients
#
# #### *Part 1 of "Pytorch: Zero to GANs"*
#
# *This post is the first in a series of tutorials on building deep learning models with PyTorch, an open source neural networks library developed and maintained by Facebook. Check out the full series:*
#
# 1. [PyTorch Basics: Tensors & Gradients](https://jovian.ml/aakashns/01-pytorch-basics)
# 2. [Linear Regression & Gradient Descent](https://jovian.ml/aakashns/02-linear-regression)
# 3. [Image Classfication using Logistic Regression](https://jovian.ml/aakashns/03-logistic-regression)
# 4. [Training Deep Neural Networks on a GPU](https://jovian.ml/aakashns/04-feedforward-nn)
# 5. [Image Classification using Convolutional Neural Networks](https://jovian.ml/aakashns/05-cifar10-cnn)
# 6. [Data Augmentation, Regularization and ResNets](https://jovian.ml/aakashns/05b-cifar10-resnet)
# 7. [Generating Images using Generative Adverserial Networks](https://jovian.ml/aakashns/06-mnist-gan)
#
# This series attempts to make PyTorch a bit more approachable for people starting out with deep learning and neural networks. In this notebook, we’ll cover the basic building blocks of PyTorch models: tensors and gradients.

# %% [markdown]
# ## System setup
#
# This tutorial takes a code-first approach towards learning PyTorch, and you should try to follow along by running and experimenting with the code yourself. The easiest way to start executing this notebook is to click the **"Run"** button at the top of this page, and select **"Run on Binder"**. This will run the notebook on [mybinder.org](https://mybinder.org), a free online service for running Jupyter notebooks.
#
# **NOTE**: *If you're running this notebook on Binder, please skip ahead to the next section.*
#
# ### Running on your computer locally
#
# We'll use the [Anaconda distribution](https://www.anaconda.com/distribution/) of Python to install libraries and manage virtual environments. For interactive coding and experimentation, we'll use [Jupyter notebooks](https://jupyter.org/). All the tutorials in this series are available as Jupyter notebooks hosted on [Jovian.ml](https://www.jovian.ml): a sharing and collaboration platform for Jupyter notebooks & machine learning experiments.
#
# Jovian.ml makes it easy to share Jupyter notebooks on the cloud by running a single command directly within Jupyter. It also captures the Python environment and libraries required to run your notebook, so anyone (including you) can reproduce your work.
#
# Here's what you need to do to get started:
#
# 1. Install Anaconda by following the [instructions given here](https://conda.io/projects/conda/en/latest/user-guide/install/index.html). You might also need to add Anaconda binaries to your system PATH to be able to run the `conda` command line tool.
#
#
# 2. Install the `jovian` Python library by the running the following command (without the `$`) on your Mac/Linux terminal or Windows command prompt:
#
# ```
# $ pip install jovian --upgrade
# ```
#
# 3. Download the notebook for this tutorial using the `jovian clone` command:
#
# ```
# $ jovian clone aakashns/01-pytorch-basics
# ```
#
# (You can copy this command to clipboard by clicking the 'Clone' button at the top of this page on Jovian.ml)
#
# Running the clone command creates a directory `01-pytorch-basics` containing a Jupyter notebook and an Anaconda environment file.
#
# ```
# $ ls 01-pytorch-basics
# 01-pytorch-basics.ipynb  environment.yml
# ```
#
# 4. Now we can enter the directory and install the required Python libraries (Jupyter, PyTorch etc.) with a single command using `jovian`:
#
# ```
# $ cd 01-pytorch-basics
# $ jovian install
# ```
#
# `jovian install` reads the `environment.yml` file, identifies the right dependencies for your operating system, creates a virtual environment with the given name (`01-pytorch-basics` by default) and installs all the required libraries inside the environment, to avoid modifying your system-wide installation of Python. It uses `conda` internally. If you face issues with `jovian install`, try running `conda env update` instead.
#
# 5. We can activate the virtual environment by running
#
# ```
# $ conda activate 01-pytorch-basics
# ```
#
# For older installations of `conda`, you might need to run the command: `source activate 01-pytorch-basics`.
#
# 6. Once the virtual environment is active, we can start Jupyter by running
#
# ```
# $ jupyter notebook
# ```
#
# 7. You can now access Jupyter's web interface by clicking the link that shows up on the terminal or by visiting http://localhost:8888 on your browser. At this point, you can click on the notebook `01-pytorch-basics.ipynb` to open it and run the code. If you want to type out the code yourself, you can also create a new notebook using the 'New' button.

# %% [markdown]
# We begin by importing PyTorch:

# %%
# Uncomment the command below if PyTorch is not installed
# !conda install pytorch cpuonly -c pytorch -y
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\customer\anaconda3
#
#   added / updated specs:
#     - cpuonly
#     - pytorch
#
#
# The following NEW packages will be INSTALLED:
#
#   cpuonly            pytorch/noarch::cpuonly-2.0-0
#   libuv              pkgs/main/win-64::libuv-1.40.0-he774522_0
#   pytorch            pytorch/win-64::pytorch-1.13.1-py3.8_cpu_0
#   pytorch-mutex      pytorch/noarch::pytorch-mutex-1.0-cpu
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... failed
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.1
#   latest version: 22.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/__pycache__/setup.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/_src/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/_src/__pycache__/aot_autograd.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/_src/__pycache__/benchmark_utils.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/_src/__pycache__/compile_utils.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/_src/__pycache__/compilers.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/_src/__pycache__/config.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/_src/__pycache__/eager_transforms.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/_src/__pycache__/fx_minifier.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/_src/__pycache__/make_functional.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/_src/__pycache__/named_members_polyfill.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/_src/__pycache__/partitioners.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/_src/__pycache__/python_key.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/_src/__pycache__/pytree_hacks.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/_src/__pycache__/top_operators_github_usage.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/_src/__pycache__/vmap.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/compile/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/dim/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/dim/__pycache__/batch_tensor.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/dim/__pycache__/delayed_mul_tensor.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/dim/__pycache__/dim.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/dim/__pycache__/magic_trace.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/dim/__pycache__/op_properties.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/dim/__pycache__/reference.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/dim/__pycache__/tree_map.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/dim/__pycache__/wrap_type.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/experimental/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/experimental/__pycache__/batch_norm_replacement.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/experimental/__pycache__/cond.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/functorch/experimental/__pycache__/ops.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch-1.13.1-py3.8.egg-info/PKG-INFO'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch-1.13.1-py3.8.egg-info/SOURCES.txt'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch-1.13.1-py3.8.egg-info/dependency_links.txt'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch-1.13.1-py3.8.egg-info/entry_points.txt'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch-1.13.1-py3.8.egg-info/requires.txt'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch-1.13.1-py3.8.egg-info/top_level.txt'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_C/_VariableFunctions.pyi'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_C/__init__.pyi'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_C/_autograd.pyi'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_C/_cudnn.pyi'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_C/_distributed_autograd.pyi'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_C/_distributed_c10d.pyi'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_C/_distributed_rpc.pyi'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_C/_distributed_rpc_testing.pyi'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_C/_functions.pyi'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_C/_functorch.pyi'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_C/_itt.pyi'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_C/_lazy.pyi'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_C/_lazy_ts_backend.pyi'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_C/_monitor.pyi'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_C/_nn.pyi'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_C/_nvtx.pyi'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_C/_onnx.pyi'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_C/_profiler.pyi'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_C/_verbose.pyi'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_C_flatbuffer/__init__.pyi'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/_VF.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/__config__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/__future__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/_appdirs.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/_classes.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/_deploy.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/_jit_internal.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/_linalg_utils.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/_lobpcg.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/_lowrank.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/_meta_registrations.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/_namedtensor_internals.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/_ops.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/_python_dispatcher.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/_six.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/_sources.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/_storage_docs.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/_tensor.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/_tensor_docs.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/_tensor_str.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/_torch_docs.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/_utils.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/_utils_internal.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/_vmap_internals.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/_weights_only_unpickler.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/functional.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/hub.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/library.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/overrides.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/quasirandom.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/random.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/return_types.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/serialization.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/storage.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/torch_version.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/types.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/__pycache__/version.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_decomp/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_decomp/__pycache__/decompositions.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_decomp/__pycache__/decompositions_for_jvp.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_dispatch/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_dispatch/__pycache__/python.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_lazy/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_lazy/__pycache__/closure.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_lazy/__pycache__/computation.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_lazy/__pycache__/config.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_lazy/__pycache__/debug.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_lazy/__pycache__/device_context.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_lazy/__pycache__/extract_compiled_graph.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_lazy/__pycache__/ir_cache.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_lazy/__pycache__/metrics.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_lazy/__pycache__/tensor_factory_functions.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_lazy/__pycache__/ts_backend.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_prims/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_prims/__pycache__/context.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_prims/__pycache__/executor.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_prims/__pycache__/nvfuser_executor.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_prims/__pycache__/nvfuser_prims.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_prims_common/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_prims_common/__pycache__/wrappers.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_refs/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_refs/__pycache__/fft.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_refs/linalg/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_refs/nn/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_refs/nn/functional/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_refs/special/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_subclasses/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_subclasses/__pycache__/fake_tensor.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_subclasses/__pycache__/fake_utils.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/_subclasses/__pycache__/meta_utils.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/amp/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/amp/__pycache__/autocast_mode.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/intrinsic/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/intrinsic/modules/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/intrinsic/modules/__pycache__/fused.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/qat/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/qat/dynamic/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/qat/dynamic/modules/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/qat/dynamic/modules/__pycache__/linear.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/qat/modules/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/qat/modules/__pycache__/conv.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/qat/modules/__pycache__/embedding_ops.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/qat/modules/__pycache__/linear.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantizable/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantizable/modules/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantizable/modules/__pycache__/activation.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantizable/modules/__pycache__/rnn.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantized/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantized/__pycache__/functional.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantized/dynamic/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantized/dynamic/modules/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantized/dynamic/modules/__pycache__/conv.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantized/dynamic/modules/__pycache__/linear.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantized/dynamic/modules/__pycache__/rnn.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantized/modules/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantized/modules/__pycache__/activation.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantized/modules/__pycache__/batchnorm.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantized/modules/__pycache__/conv.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantized/modules/__pycache__/dropout.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantized/modules/__pycache__/embedding_ops.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantized/modules/__pycache__/functional_modules.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantized/modules/__pycache__/linear.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantized/modules/__pycache__/normalization.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantized/modules/__pycache__/rnn.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantized/modules/__pycache__/utils.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantized/reference/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantized/reference/modules/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantized/reference/modules/__pycache__/conv.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantized/reference/modules/__pycache__/linear.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantized/reference/modules/__pycache__/rnn.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/ao/nn/quantized/reference/modules/__pycache__/sparse.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# ...
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/utils/model_dump/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/utils/model_dump/__pycache__/__main__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/utils/model_dump/htm.mjs'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/utils/model_dump/preact.mjs'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/utils/tensorboard/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/utils/tensorboard/__pycache__/_caffe2_graph.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/utils/tensorboard/__pycache__/_convert_np.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/utils/tensorboard/__pycache__/_embedding.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/utils/tensorboard/__pycache__/_onnx_graph.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/utils/tensorboard/__pycache__/_proto_graph.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/utils/tensorboard/__pycache__/_pytorch_graph.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/utils/tensorboard/__pycache__/_utils.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/utils/tensorboard/__pycache__/summary.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torch/utils/tensorboard/__pycache__/writer.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/__pycache__/code_template.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/__pycache__/context.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/__pycache__/gen.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/__pycache__/gen_backend_stubs.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/__pycache__/gen_functionalization_type.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/__pycache__/gen_lazy_tensor.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/__pycache__/gen_vmap_plumbing.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/__pycache__/local.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/__pycache__/model.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/__pycache__/native_function_generation.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/__pycache__/utils.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/api/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/api/__pycache__/autograd.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/api/__pycache__/cpp.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/api/__pycache__/dispatcher.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/api/__pycache__/functionalization.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/api/__pycache__/lazy.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/api/__pycache__/meta.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/api/__pycache__/native.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/api/__pycache__/python.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/api/__pycache__/structured.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/api/__pycache__/translate.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/api/__pycache__/types.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/api/__pycache__/ufunc.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/api/__pycache__/unboxing.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/dest/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/dest/__pycache__/lazy_ir.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/dest/__pycache__/lazy_ts_lowering.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/dest/__pycache__/native_functions.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/dest/__pycache__/register_dispatch_key.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/dest/__pycache__/ufunc.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/operator_versions/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/operator_versions/__pycache__/gen_mobile_upgraders.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/operator_versions/__pycache__/gen_mobile_upgraders_constant.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/packaged/ATen/templates/UfuncCUDA.cu'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/selective_build/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/selective_build/__pycache__/operator.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/selective_build/__pycache__/selector.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/static_runtime/__pycache__/__init__.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/static_runtime/__pycache__/config.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/static_runtime/__pycache__/gen_static_runtime_ops.cpython-38.pyc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at C:\Users\customer\anaconda3\pkgs\pytorch-1.13.1-py3.8_cpu_0
# appears to be corrupted. The path 'Lib/site-packages/torchgen/static_runtime/__pycache__/generator.cpython-38.pyc'
# specified in the package manifest cannot be found.

# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import torch
#
# ModuleNotFoundError: No module named 'torch'

# %% [markdown]
# ## Tensors
#
# At its core, PyTorch is a library for processing tensors. A tensor is a number, vector, matrix or any n-dimensional array. Let's create a tensor with a single number:

# %%
# Number
t1 = torch.tensor(4.)
t1
# Out:
# tensor(4.)

# %% [markdown]
# `4.` is a shorthand for `4.0`. It is used to indicate to Python (and PyTorch) that you want to create a floating point number. We can verify this by checking the `dtype` attribute of our tensor:

# %%
t1.dtype
# Out:
# torch.float32

# %% [markdown]
# Let's try creating slightly more complex tensors:

# %%
# Vector
t2 = torch.tensor([1., 2, 3, 4])
t2
# Out:
# tensor([1., 2., 3., 4.])

# %%
# Matrix
t3 = torch.tensor([[5., 6], 
                   [7, 8], 
                   [9, 10]])
t3
# Out:
# tensor([[ 5.,  6.],
#         [ 7.,  8.],
#         [ 9., 10.]])

# %%
# 3-dimensional array
t4 = torch.tensor([
    [[11, 12, 13], 
     [13, 14, 15]], 
    [[15, 16, 17], 
     [17, 18, 19.]]])
t4
# Out:
# tensor([[[11., 12., 13.],
#          [13., 14., 15.]],
#
#         [[15., 16., 17.],
#          [17., 18., 19.]]])

# %% [markdown]
# Tensors can have any number of dimensions, and different lengths along each dimension. We can inspect the length along each dimension using the `.shape` property of a tensor.

# %%
print(t1)
t1.shape
# Out:
# tensor(4.)
# torch.Size([])

# %%
print(t2)
t2.shape
# Out:
# tensor([1., 2., 3., 4.])
# torch.Size([4])

# %%
print(t3)
t3.shape
# Out:
# tensor([[ 5.,  6.],
#         [ 7.,  8.],
#         [ 9., 10.]])
# torch.Size([3, 2])

# %%
print(t4)
t4.shape
# Out:
# tensor([[[11., 12., 13.],
#          [13., 14., 15.]],
#
#         [[15., 16., 17.],
#          [17., 18., 19.]]])
# torch.Size([2, 2, 3])

# %% [markdown]
# ## Tensor operations and gradients
#
# We can combine tensors with the usual arithmetic operations. Let's look an example:

# %%
# Create tensors.
x = torch.tensor(3.)
w = torch.tensor(4., requires_grad=True)
b = torch.tensor(5., requires_grad=True)
x, w, b
# Out:
# (tensor(3.), tensor(4., requires_grad=True), tensor(5., requires_grad=True))

# %% [markdown]
# We've created 3 tensors `x`, `w` and `b`, all numbers. `w` and `b` have an additional parameter `requires_grad` set to `True`. We'll see what it does in just a moment.
#
# Let's create a new tensor `y` by combining these tensors:

# %%
# Arithmetic operations
y = w * x + b
y
# Out:
# tensor(17., grad_fn=<AddBackward0>)

# %% [markdown]
# As expected, `y` is a tensor with the value `3 * 4 + 5 = 17`. What makes PyTorch special is that we can automatically compute the derivative of `y` w.r.t. the tensors that have `requires_grad` set to `True` i.e. w and b. To compute the derivatives, we can call the `.backward` method on our result `y`.

# %%
# Compute derivatives
y.backward()

# %% [markdown]
# The derivates of `y` w.r.t the input tensors are stored in the `.grad` property of the respective tensors.

# %%
# Display gradients
print('dy/dx:', x.grad)
print('dy/dw:', w.grad)
print('dy/db:', b.grad)
# Out:
# dy/dx: None
# dy/dw: tensor(3.)
# dy/db: tensor(1.)

# %% [markdown]
# As expected, `dy/dw` has the same value as `x` i.e. `3`, and `dy/db` has the value `1`. Note that `x.grad` is `None`, because `x` doesn't have `requires_grad` set to `True`.
#
# The "grad" in `w.grad` stands for gradient, which is another term for derivative, used mainly when dealing with matrices.

# %% [markdown]
# ## Interoperability with Numpy
#
# [Numpy](http://www.numpy.org/) is a popular open source library used for mathematical and scientific computing in Python. It enables efficient operations on large multi-dimensional arrays, and has a large ecosystem of supporting libraries:
#
# * [Matplotlib](https://matplotlib.org/) for plotting and visualization
# * [OpenCV](https://opencv.org/) for image and video processing
# * [Pandas](https://pandas.pydata.org/) for file I/O and data analysis
#
# Instead of reinventing the wheel, PyTorch interoperates really well with Numpy to leverage its existing ecosystem of tools and libraries.

# %% [markdown]
# Here's how we create an array in Numpy:

# %%
import numpy as np

x = np.array([[1, 2], [3, 4.]])
x
# Out:
# array([[1., 2.],
#        [3., 4.]])

# %% [markdown]
# We can convert a Numpy array to a PyTorch tensor using `torch.from_numpy`.

# %%
# Convert the numpy array to a torch tensor.
y = torch.from_numpy(x)
y
# Out:
# tensor([[1., 2.],
#         [3., 4.]], dtype=torch.float64)

# %% [markdown]
# Let's verify that the numpy array and torch tensor have similar data types.

# %%
x.dtype, y.dtype
# Out:
# (dtype('float64'), torch.float64)

# %% [markdown]
# We can convert a PyTorch tensor to a Numpy array using the `.numpy` method of a tensor.

# %%
# Convert a torch tensor to a numpy array
z = y.numpy()
z
# Out:
# array([[1., 2.],
#        [3., 4.]])

# %% [markdown]
# The interoperability between PyTorch and Numpy is really important because most datasets you'll work with will likely be read and preprocessed as Numpy arrays.

# %% [markdown]
# ## Commit and upload the notebook
#
# As a final step, we can save and commit out work using the `jovian` library.

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..

# %% [markdown]
# `jovian.commit` uploads the notebook to your [Jovian.ml](https://www.jovian.ml) account, captures the Python environment and creates a sharable link for your notebook as shown above. You can use this link to share your work and let anyone reproduce it easily with the `jovian clone` command. Jovian also includes a powerful commenting interface, so you (and others) can discuss & comment on specific parts of your notebook:
#
# ![commenting on jovian](https://cdn-images-1.medium.com/max/1600/1*b4snnr_5Ve5Nyq60iDtuuw.png)

# %% [markdown]
# ## Further Reading
#
# Tensors in PyTorch support a variety of operations, and what we've covered here is by no means exhaustive. You can learn more about tensors and tensor operations here: https://pytorch.org/docs/stable/tensors.html
#
# You can take advantage of the interactive Jupyter environment to experiment with tensors and try different combinations of operations discussed above. Here are some things to try out:
#
# 1. What if one or more `x`, `w` or `b` were matrices, instead of numbers, in the above example? What would the result `y` and the gradients `w.grad` and `b.grad` look like in this case?
#
# 2. What if `y` was a matrix created using `torch.tensor`, with each element of the matrix expressed as a combination of numeric tensors `x`, `w` and `b`?
#
# 3. What if we had a chain of operations instead of just one i.e. `y = x * w + b`, `z = l * y + m`, `w = c * z + d` and so on? What would calling `w.grad` do?
#
# If you're interested, you can learn more about matrix derivates on Wikipedia (although it's not necessary for following along with this series of tutorials): https://en.wikipedia.org/wiki/Matrix_calculus#Derivatives_with_matrices

# %% [markdown]
# With this, we complete our discussion of tensors and gradients in PyTorch, and we're ready to move on to the next topic: *Linear regression*.
#
# ## Credits
#
# The material in this series is heavily inspired by the following resources:
#
# 1. [PyTorch Tutorial for Deep Learning Researchers](https://github.com/yunjey/pytorch-tutorial) by Yunjey Choi:
#
# 2. [FastAI development notebooks](https://github.com/fastai/fastai_docs/tree/master/dev_nb) by Jeremy Howard:
